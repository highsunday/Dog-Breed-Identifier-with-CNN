# %%
from keras.models import load_model
import os
import numpy as np
from PIL import Image
from glob import glob
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
model = load_model('model/model_V7_50epochs.h5')

# %%
test_path='predict_images'

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# inception_v3 (Model)         (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_6 (Dense)              (None, 120)               30840
# ...
# Total params: 26,552,472
# Trainable params: 15,864,568
# Non-trainable params: 10,687,904
# _________________________________________________________________

# %%
img_size=150
img = Image.open('predict_images/image.jpeg')
img = img.resize((img_size,img_size)) #图片resize

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x6480C6190>

# %%
arr = np.asarray(img)  #图片转array
arr
# Out:
# array([[[ 70,  67,  74],
#         [ 70,  67,  74],
#         [ 71,  68,  75],
#         ...,
#         [ 25,  24,  30],
#         [ 25,  24,  30],
#         [ 25,  24,  30]],
#
#        [[ 68,  65,  72],
#         [ 69,  66,  73],
#         [ 70,  67,  74],
#         ...,
#         [ 27,  26,  32],
#         [ 27,  26,  32],
#         [ 27,  26,  32]],
#
#        [[ 66,  63,  70],
#         [ 66,  63,  70],
#         [ 68,  65,  72],
#         ...,
#         [ 28,  27,  33],
#         [ 28,  27,  33],
#         [ 28,  27,  33]],
#
#        ...,
#
#        [[172, 171, 189],
#         [177, 176, 194],
#         [174, 173, 191],
#         ...,
#         [169, 171, 192],
#         [176, 178, 199],
#         [187, 189, 210]],
#
#        [[169, 168, 186],
#         [174, 173, 191],
#         [176, 175, 193],
#         ...,
#         [174, 176, 197],
#         [176, 177, 198],
#         [170, 172, 193]],
#
#        [[176, 175, 193],
#         [174, 173, 191],
#         [179, 178, 196],
# ...

# %%
arr.shape
# Out:
# (150, 150, 3)

# %%
arr=arr.reshape(1,150,150,3)

# %%
res=model.predict(arr)
res
